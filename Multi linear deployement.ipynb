# %%
import pickle

# %%
loaded_model=pickle.load(open("finalised_model_linear.sav",'rb'))#loading the file,here rb-read binary
result=loaded_model.predict([[15505.73,127382.30,35534.17,0,1]])#prediction
# Out:
# C:\Users\Christina\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[59919.85304061]])
